# %%
from __future__ import print_function, division
import pandas as pd

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ds_df = pd.read_excel("dataset_details.xlsx")

# %%
.ids_df
# Out:
#     Unnamed: 0               Unnamed: 1           0           1           2  \
# 0     R001.jpg                 centroid  (649, 175)  (833, 190)  (603, 138)
# 1          NaN              transitions        1691        2245        2595
# 2          NaN             aspect_ratio           4           5           3
# 3          NaN        inclination_angle    0.263381    0.224255    0.224981
# 4          NaN  norm_black_pixels_angle    0.381017    0.337466    0.196389
# 5          NaN       no_of_black_pixels       32609       45454       48834
# 6          NaN          normalized_size      12.124     9.57526     11.6535
# 7     R002.jpg                 centroid  (599, 220)  (798, 213)  (563, 155)
# 8          NaN              transitions        1471        2315        2497
# 9          NaN             aspect_ratio           4           4           2
# 10         NaN        inclination_angle    0.351984    0.260836    0.268655
# ...

# %%
for i in range(1, 7):
    print("**********************")
    print("Feature: " + ds_df.iloc[i].iloc[1])
    print("Histogram:")
    ds_df.iloc[i][2:].hist(bins=50)
    plt.show()
    print("Description:")
    print(ds_df.iloc[i][2:].describe())
    print()
# Out:
# **********************
# Feature: transitions
# Histogram:
# Description:
# count      64
# unique     62
# top       112
# freq        2
# Name: 1, dtype: int64
#
# **********************
# Feature: aspect_ratio
# Histogram:
# Description:
# count     64
# unique    13
# top        5
# freq      13
# Name: 2, dtype: int64
#
# **********************
# Feature: inclination_angle
# Histogram:
# Description:
# count     64.000000
# unique    63.000000
# top        1.277207
# freq       2.000000
# Name: 3, dtype: float64
#
# **********************
# Feature: norm_black_pixels_angle
# Histogram:
# Description:
# count     64.0
# unique    62.0
# top        0.0
# freq       3.0
# Name: 4, dtype: float64
#
# **********************
# Feature: no_of_black_pixels
# Histogram:
# Description:
# count       64
# unique      64
# top       4110
# freq         1
# Name: 5, dtype: int64
#
# **********************
# Feature: normalized_size
# Histogram:
# Description:
# count     64.000000
# ...
